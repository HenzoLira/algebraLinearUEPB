# %% [markdown]
# # 🎓 Álgebra Linear — Unidade 1
# ### UEPB | Prof.ª Thiciany Matsudo Iwano
# **Referência:** BOLDRINI, J. L. et al. *Álgebra Linear*. Harper & Row, 1984.
#
# ---
#
# ## Sobre este Repositório
#
# Este repositório contém uma série de notebooks Jupyter dedicados ao estudo dos tópicos da **Unidade 1 de Álgebra Linear**, combinando teoria rigorosa baseada no Boldrini com visualizações geométricas e implementação prática em Python + SymPy.
#
# > **Uso de IA:** este material foi estruturado com auxílio de modelos de linguagem, com revisão e validação do conteúdo pelo autor.
#
# ---
#
# ## 🗺️ Roadmap — Ordem de Estudo
#
# | Notebook | Tópico |
# |----------|--------|
# | `01_matrizes.ipynb` | Definição, tipos especiais e operações |
# | `02_sistemas_lineares.ipynb` | Definição, Método de Gauss, tipos de solução |
# | `03_espacos_vetoriais.ipynb` | Definição formal e os 8 axiomas |
# | `04_subespacos_vetoriais.ipynb` | Definição, verificação, exemplos |
# | `05_combinacao_linear.ipynb` | Definição, cálculo e exemplos |
# | `06_span.ipynb` | Subespaço gerado, notação e exemplos |
# | `07_li_ld.ipynb` | Independência linear, verificação, proposição útil |
# | `08_base_e_dimensao.ipynb` | Base, base canônica, dimensão |
#
# ---
#
# ## 🛠️ Dependências

# %%
# Execute esta célula para instalar as dependências necessárias
# (já disponíveis no Google Colab)

# !pip install sympy numpy matplotlib

import sympy
import numpy
import matplotlib
print(f"SymPy:      {sympy.__version__}")
print(f"NumPy:      {numpy.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print("\n✅ Tudo pronto!")

# %% [markdown]
# ---
# ## 📚 Referências Principais
#
# - **BOLDRINI, J. L. et al.** *Álgebra Linear*. 3. ed. São Paulo: Harper & Row, 1984.
# - **Slides da disciplina** — Prof.ª Thiciany Matsudo Iwano — UEPB, 2025/2026.
# - **STRANG, Gilbert.** *Introduction to Linear Algebra*. Wellesley-Cambridge Press.
